# %%
import pandas as pd

# 設定 CSV 檔案的路徑
csv_file_path_NM1 = 'NightMarket01.csv'
csv_file_path_NM2 = 'NightMarket02.csv'



# 使用 pandas 的 read_csv 函式讀取 CSV 檔案並將其轉換為 DataFrame
df_NM1 = pd.read_csv(csv_file_path_NM1)
df_NM2 = pd.read_csv(csv_file_path_NM2)

# 從 DataFrame 中取出學生名稱欄位，假設欄位名稱為 '學生名稱'，你可以根據實際情況調整
VenderName_NM1 = df_NM1['攤販名稱']
VenderName_NM2 = df_NM2['攤販名稱']


# 將學生名稱轉換為 set 資料型態
VenderName_NM1_set = set(VenderName_NM1)
VenderName_NM2_set = set(VenderName_NM2)

print("夜市1的攤販有:",VenderName_NM1_set)
print("夜市2的攤販有:",VenderName_NM2_set)

print("同時在兩個夜市的攤販有:",VenderName_NM1_set & VenderName_NM1_set)
# Out:
# 夜市1的攤販有: {'小明炒麵', '王大叔水果攤', '阿婆豆花', '阿姨鹹粥', '阿強炸雞排', '小李烤玉米', '阿財滷味'}
# 夜市2的攤販有: {'61,277', '50,220', '66,978', '102,597', '69,309', '844,402', '62,414', '47,667', '68,562', '64,891', '44,649', '68,540', '48,746', '95,372', '94,543', '60,705', '59,001', '77,316', '69,422', '57,673', '56,696', '62,241', '70,195', nan, '89,386', '44,174', '62,407', '76,835', '40,171', '51,125', '88,555', '73,074', '95,320', '55,846', '45,349', '70,688', '523,913', '69,269', '36,699', '36,527', '57,865', '65,706', '41,147', '69,893', '43,800', '50,268', '75,181', '61,078', '76,111', '65,258', '47,780', '53,310', '56,202', '49,547', '840,129', '98,964', '66,957', '64,640', '66,654', '82,515', '52,393', '46,636', '79,216', '613,187', '50,187', '87,563', '68,077', '984,869', '49,887', '63,513', '657,166', '69,792', '71,687', '79,986', '59,118', '75,722', '876,054', '45,898', '68,299', '42,868', '69,778', '70,669', '49,074', '50,593', '796,815', '36,272', '50,375', '57,883', '718,831', '54,369', '46,699', '45,900', '65,675', '70,206', '74,274', '63,831', '71,507', '71,972', '51,468', '63,615', '49,524', '60,823', '50,879', '50,862', '62,111', '54,417', '83,801', '69,187', '57,310', '51,577', '65,700', '41,361', '101,377', '69,440', '43,219', '82,471', '82,087', '71,827', '47,516', '83,108', '98,079', '30,646', '1,016,484', '43,902', '30,947', '42,158', '70,967', '79,315', '68,173', '49,423', '23,822', '88,919', '504,938', '72,930', '57,462', '75,178', '49,815', '657,495', '54,521', '58,470', '65,270', '43,123', '110,710', '49,171', '85,818', '695,471', '52,528', '79,181', '80,277', '67,333', '76,104', '60,463', '139,455', '94,441', '57,566', '106,950', '68,347', '81,193', '69,184', '51,198', '35,397', '65,915', '88,765', '34,934', '74,110', '56,680'}
# 同時在兩個夜市的攤販有: {'小明炒麵', '小李烤玉米', '王大叔水果攤', '阿婆豆花', '阿財滷味', '阿姨鹹粥', '阿強炸雞排'}
